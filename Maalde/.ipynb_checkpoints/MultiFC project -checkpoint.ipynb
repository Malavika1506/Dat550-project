# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras as tfk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c775ccf90eda> in <module>
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
# ----> 6 import tensorflow as tf
#       7 from tensorflow import keras
#       8 import tensorflow.keras as tfk
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
df_train = pd.read_csv('../data/train.tsv', '\t')
df_train.columns=['claimID', 'claim', 'label', 'claimURL', 'reason', 'categories', 'speaker', 'checker', 'tags', 'articleTitle', 'publishDate', 'claimDate', 'entities']
df_train.set_index('claimID', inplace = True)
df_train

# %%
df_test = pd.read_csv('../data/test.tsv', '\t')
df_test.columns=['claimID', 'claim','claimURL', 'reason', 'categories', 'speaker', 'checker', 'tags', 'articleTitle', 'publishDate', 'claimDate', 'entities']
df_test.set_index('claimID', inplace = True)
df_test
# Out:
#                                                         claim  \
# claimID
# pomt-02596  Says in 2000, Fox News broke the story of Geor...
# snes-00569  A video shows a powerful jet of water flipping...
# pomt-14237  My numbers are better right now than Ronald Re...
# snes-05947  The U.S. Congress is considering passage of th...
# pomt-07681  Bing Energy said it decided to move to Florida...
# snes-01813  A photograph shows actor James Earl Jones dres...
# snes-02041  A home pregnancy test can detect testicular ca...
# snes-06044  Photographs show a mass re-enlistment ceremony...
# snes-02334                           Crisis Actors Uncovered?
# goop-00309  Ariel Winter, Burt Reynolds Were Feuding Befor...
# goop-01914    Angelina Jolie Headed For “Physical Meltdown,”
# pose-00712  Will guarantee "access to at least two years o...
# tron-00776                  Julie Andrews singing about aging
# tron-00817  AC/DC Is Retiring Because Guitarist Malcolm Yo...
# ...

# %%
df_train['label'].value_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-92dd664149d9> in <module>
# ----> 1 df_train['label'].value_counts
#
# NameError: name 'df_train' is not defined

# %%
data = df_train.append(df_test, ignore_index = False)
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
data
# Out:
#                                                  articleTitle   categories  \
# claimID
# pomt-09611                                               None         None
# tron-00214                       Forward an email for Jasmine  9-11-attack
# snes-04484  Pope Francis Shocks World, Endorses Donald Tru...    Junk News
# pomt-06704                                               None         None
# pomt-15232                                               None         None
# ...                                                       ...          ...
# vees-00500  Is that so? Duterte-De Lima ‘word war’ on rice...         None
# snes-03319                       Confessions for the Holidays      Soapbox
# pomt-12071                                               None         None
# vees-00229  VERA FILES FACT CHECK: Kuwait DID NOT YIELD to...         None
# goop-01503  Blac Chyna Does NOT “Suspect” Kardashians Are ...         None
#
#                     checker  \
# claimID
# ...

# %%
data.shape
# Out:
# (31356, 12)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                                                  articleTitle   categories  \
# claimID
# pomt-09611                                               None         None
# tron-00214                       Forward an email for Jasmine  9-11-attack
# snes-04484  Pope Francis Shocks World, Endorses Donald Tru...    Junk News
# pomt-06704                                               None         None
# pomt-15232                                               None         None
# ...                                                       ...          ...
# vees-00500  Is that so? Duterte-De Lima ‘word war’ on rice...         None
# snes-03319                       Confessions for the Holidays      Soapbox
# pomt-12071                                               None         None
# vees-00229  VERA FILES FACT CHECK: Kuwait DID NOT YIELD to...         None
# goop-01503  Blac Chyna Does NOT “Suspect” Kardashians Are ...         None
#
# ...

# %% [markdown]
# ### Model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, LSTM, Bidirectional, Dense, Dropout
from tensorflow.keras.models import Model

from sklearn.metrics import confusion_matrix, classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-7238dda6fd7d> in <module>
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras.layers import Input, Embedding, LSTM, Bidirectional, Dense, Dropout
#       3 from tensorflow.keras.models import Model
#       4
#       5 from sklearn.metrics import confusion_matrix, classification_report
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
main_input = Input(shape =(31356,12)   , dtype = ''  , name = 'main_input')
E = Embedding(output_dim = , input_dim = , input_length = )(main_input)
bilstm_out = Bidirectional(LSTM(30)).(E)

## auxiliary output

aux_output = Dense(1, activation = 'softmax', name = 'aux_output').(bilstm_out)

# %%
## Concatenation

aux_input = Input(shape = (,), name = 'aux_input')
x = tensorflow.keras.layers.concatenate([bilstm_out, aux_input])

##Dense layers

x = Dense(60, activation = 'relu')(x)
x = Dense(60, activation = 'relu')(x)

main_output = Dense(1,activation = 'softmax', name = 'main_output')(x)

# %%
###Model

model = Model(inputs =[main_input, aux_input], outputs = [main_output, aux_output])
model.compile(optimizer = 'rmsprop', loss ={'main_output': 'mean_squared_error', 'aux_output':'mean_squared_error'}, loss_weights = {'main_output':1., 'aux_output'= 0.1})
model.fit({'main_input':xtrain_data, 'aux_input': dev_data},{'main_output': ytrain_labels, 'aux_outout': dev_labels}, epochs = 3, bathsize = 100)

# %%
## predict

prediction = model.predict([true_labels, predicted_labels])

# %%
##Metrics

print(metrics.confusion_matrix(true_labels, predicted_labels))

print(metrics.classification_report(true_labels, predicted_labels, digits = 3))
