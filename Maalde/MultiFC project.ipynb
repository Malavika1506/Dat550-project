# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras as tfk

# %%
df_train = pd.read_csv('../data/train.tsv', '\t')
df_train.columns=['claimID', 'claim', 'label', 'claimURL', 'reason', 'categories', 'speaker', 'checker', 'tags', 'articleTitle', 'publishDate', 'claimDate', 'entities']
df_train.set_index('claimID', inplace = True)
df_train
# Out:
#                                                         claim           label  \
# claimID
# pomt-09611  No Democratic campaign for (Fla.) governor has...            true
# tron-00214                       Forward an email for Jasmine        fiction!
# snes-04484  Pope Francis endorsed Donald Trump for president.           false
# pomt-06704   Says Ron Paul insisted FEMA should be shut down.            true
# pomt-15232  Says Hillary Clinton has "been in office and i...    mostly false
# ...                                                       ...             ...
# snes-00146  Did Google Fail to Promote President Trump’s S...           false
# abbc-00012  Federal MP Bob Katter's response to a question...      in-the-red
# pomt-05523  Sen. Sherrod Brown’s vote helped pass "Barack ...  pants on fire!
# pomt-10920  Even the CBO numbers show now that the entire ...           false
# pomt-11312  Obama Announces Bid To Become UN Secretary Gen...  pants on fire!
#
# ...

# %%
df_test = pd.read_csv('../data/test.tsv', '\t')
df_test.columns=['claimID', 'claim','claimURL', 'reason', 'categories', 'speaker', 'checker', 'tags', 'articleTitle', 'publishDate', 'claimDate', 'entities']
df_test.set_index('claimID', inplace = True)
df_test
# Out:
#                                                         claim  \
# claimID
# pomt-02596  Says in 2000, Fox News broke the story of Geor...
# snes-00569  A video shows a powerful jet of water flipping...
# pomt-14237  My numbers are better right now than Ronald Re...
# snes-05947  The U.S. Congress is considering passage of th...
# pomt-07681  Bing Energy said it decided to move to Florida...
# ...                                                       ...
# vees-00500  Is that so? Duterte-De Lima ‘word war’ on rice...
# snes-03319  Transcript reproduces Ben Stein's television c...
# pomt-12071  My grandparents were proud immigrants to the U...
# vees-00229  VERA FILES FACT CHECK: Kuwait DID YIELD to Dut...
# goop-01503  Blac Chyna Does “Suspect” Kardashians Are “Beh...
#
#                                                      claimURL  \
# claimID
# pomt-02596  /punditfact/statements/2014/jan/27/ann-coulter...
# snes-00569  https://www.snopes.com/fact-check/child-flippe...
# ...

# %%
df_train['label'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of claimID
# pomt-09611              true
# tron-00214          fiction!
# snes-04484             false
# pomt-06704              true
# pomt-15232      mostly false
#                    ...
# snes-00146             false
# abbc-00012        in-the-red
# pomt-05523    pants on fire!
# pomt-10920             false
# pomt-11312    pants on fire!
# Name: label, Length: 27870, dtype: object>

# %%
data = df_train.append(df_test, ignore_index = False)

# %%
data
# Out:
#                                                  articleTitle   categories  \
# claimID
# pomt-09611                                               None         None
# tron-00214                       Forward an email for Jasmine  9-11-attack
# snes-04484  Pope Francis Shocks World, Endorses Donald Tru...    Junk News
# pomt-06704                                               None         None
# pomt-15232                                               None         None
# ...                                                       ...          ...
# vees-00500  Is that so? Duterte-De Lima ‘word war’ on rice...         None
# snes-03319                       Confessions for the Holidays      Soapbox
# pomt-12071                                               None         None
# vees-00229  VERA FILES FACT CHECK: Kuwait DID NOT YIELD to...         None
# goop-01503  Blac Chyna Does NOT “Suspect” Kardashians Are ...         None
#
#                     checker  \
# claimID
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                                                  articleTitle   categories  \
# claimID
# pomt-09611                                               None         None
# tron-00214                       Forward an email for Jasmine  9-11-attack
# snes-04484  Pope Francis Shocks World, Endorses Donald Tru...    Junk News
# pomt-06704                                               None         None
# pomt-15232                                               None         None
# ...                                                       ...          ...
# vees-00500  Is that so? Duterte-De Lima ‘word war’ on rice...         None
# snes-03319                       Confessions for the Holidays      Soapbox
# pomt-12071                                               None         None
# vees-00229  VERA FILES FACT CHECK: Kuwait DID NOT YIELD to...         None
# goop-01503  Blac Chyna Does NOT “Suspect” Kardashians Are ...         None
#
# ...
